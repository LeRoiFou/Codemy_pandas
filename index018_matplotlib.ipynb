# %% [markdown]
# ##### Cours : Histograms With Matplotlib - Pandas For Machine Learning 18
# ##### Lien : https://www.youtube.com/watch?v=siUJqANJhHc
#
#
# ##### Date : 10-01-23
# ***

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from numpy.random import rand

# %%
# Create a quick DF
my_df = pd.DataFrame(rand(100, 4), columns=['Mon', 'Tues', 'Wed', 'Thur'])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   0.937955  0.210294  0.877557  0.118034
# 1   0.866216  0.717771  0.851799  0.675858
# 2   0.640361  0.043473  0.375108  0.196774
# 3   0.401734  0.667958  0.597322  0.459309
# 4   0.466171  0.734529  0.308616  0.817613
# ..       ...       ...       ...       ...
# 95  0.483173  0.721827  0.771916  0.532027
# 96  0.668836  0.184817  0.839682  0.705837
# 97  0.153170  0.747846  0.801741  0.531957
# 98  0.461865  0.062424  0.788301  0.219083
# 99  0.799357  0.981103  0.224507  0.026617
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df['Wed'].hist()
# Out:
# <AxesSubplot: >

# %%
# Histogram with Smaller bins, 50, 20
# Histogram
my_df['Wed'].hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
# Another way without grid bars
my_df['Wed'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
my_df['Wed'].plot(kind='hist', bins=20, grid=True, legend=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>
